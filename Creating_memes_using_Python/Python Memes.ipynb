# %%
import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont

# %%
img = Image.new(mode="RGB", size=(200, 100), color=(0, 0, 0))

# %%
from PIL import ImageDraw
draw = ImageDraw.Draw(img)

# %%
text = 'Hello World!'

# %%
draw.text((50, 30), text, fill=(255, 140, 0))

# %%
plt.imshow(img)
plt.show()

# %%
font = ImageFont.truetype(r'C:\Users\nirup\Downloads\Afacad_Flux\static\AfacadFlux-Light.ttf', 15)
draw.text((50, 30), text, font=font, fill=(255, 140, 0))

# %%
img = Image.open(r"C:\Users\nirup\Downloads\meme_1.PNG")
DRAW = ImageDraw.Draw(img)
font = ImageFont.truetype(r'C:\Users\nirup\Downloads\Afacad_Flux\static\AfacadFlux-Light.ttf', 100)
DRAW.text((900, 50), "Scikit-learn", fill=(0, 0, 0), font=font)
DRAW.text((600, 10), "Me", fill=(0, 0, 0), font=font)
DRAW.text((100, 60), "Keras", fill=(0, 0, 0), font=font)
plt.imshow(img)

# %%
output_file = (r"C:\Users\nirup\Downloads\meme_output.jpg")

# %%
img.convert("RGB").save(output_file, "JPEG")

# %%
print(f"Image saved as {output_file}")
# Out:
# Image saved as C:\Users\nirup\Downloads\meme_output.jpg
